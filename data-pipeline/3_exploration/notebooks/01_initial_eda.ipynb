# %% [markdown]
# # Analyse Exploratoire Initiale - EcoLabel-MS
#
# Exploration des données produits collectées depuis Open Food Facts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Chargement des données
df = pd.read_csv('../../datasets/raw/openfoodfacts_5k.csv.gz')
print(f"Dataset: {len(df)} produits")
df.head()
